# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import sklearn as sk

# %%
data = pd.read_csv("Data_Etudiants_2023.txt", sep=";")

# %%
data
# Out:
#        T1_1h_R1  T1_2h_R1  T1_3h_R1  T1_4h_R1  T1_5h_R1  T1_6h_R1  T2_1h_R1  \
# G1     0.167009  0.682881 -0.180178  0.075348 -0.001642  0.501269 -0.590392
# G2     0.187621  0.815365 -0.045735  0.181518  0.467269 -0.759716  0.377821
# G3    -0.052076 -0.029437  0.261409 -0.317389 -0.386266  0.420686  0.208241
# G4    -0.230785 -0.753947 -0.244923 -0.704300 -0.117073 -0.382628  0.409572
# G5    -0.205473 -0.688821 -0.181084 -0.066565  0.521709  0.448094 -0.449139
# ...         ...       ...       ...       ...       ...       ...       ...
# G1611 -0.055346  0.194969 -0.095603  0.469783 -0.096975 -0.275488  0.354792
# G1612  0.097380  0.036748  0.015044 -0.282861  0.060536  0.254775  0.516285
# G1613  0.075964  0.118213  0.075933  0.311468 -0.126794 -0.112648  0.207900
# G1614 -0.078319 -0.817539 -0.349089 -0.310730 -0.234645  0.022602 -0.264489
# G1615  0.043931  0.556120 -0.155317  0.018719 -0.317713  0.295900 -0.158306
#
# ...

# %%
data.head()
# Out:
#     T1_1h_R1  T1_2h_R1  T1_3h_R1  T1_4h_R1  T1_5h_R1  T1_6h_R1  T2_1h_R1  \
# G1  0.167009  0.682881 -0.180178  0.075348 -0.001642  0.501269 -0.590392
# G2  0.187621  0.815365 -0.045735  0.181518  0.467269 -0.759716  0.377821
# G3 -0.052076 -0.029437  0.261409 -0.317389 -0.386266  0.420686  0.208241
# G4 -0.230785 -0.753947 -0.244923 -0.704300 -0.117073 -0.382628  0.409572
# G5 -0.205473 -0.688821 -0.181084 -0.066565  0.521709  0.448094 -0.449139
#
#     T2_2h_R1  T2_3h_R1  T2_4h_R1  ...  T2_3h_R2  T2_4h_R2  T2_5h_R2  T2_6h_R2  \
# G1  0.192059  0.815695  2.266757  ...  0.263301  1.907773  2.466574  3.396958
# G2  2.510333  2.387657  2.998971  ...  2.761253  2.440673  2.381917  2.260745
# G3 -0.998712 -2.583815 -3.372319  ... -1.769917 -3.323948 -2.632251 -2.877618
# G4  0.233312  0.967910  0.890278  ...  1.024548  2.059611  1.737199  2.359006
# G5 -1.514382 -3.815376 -2.503011  ... -2.398936 -2.551766 -2.474437 -3.144543
#
# ...

# %%
data.describe()
# Out:
#           T1_1h_R1     T1_2h_R1     T1_3h_R1     T1_4h_R1     T1_5h_R1  \
# count  1615.000000  1615.000000  1615.000000  1615.000000  1615.000000
# mean     -0.022214     0.063342    -0.046326     0.018038    -0.088401
# std       0.342602     0.597517     0.514850     0.614582     0.562864
# min      -3.584361    -4.172482    -2.662107    -2.856215    -5.510584
# 25%      -0.153601    -0.170727    -0.239068    -0.257483    -0.297658
# 50%      -0.011635     0.055210    -0.043636     0.060429    -0.099623
# 75%       0.129234     0.317258     0.142963     0.335523     0.134384
# max       2.899491     5.042130     4.773785     4.383393     3.312692
#
#           T1_6h_R1     T2_1h_R1     T2_2h_R1     T2_3h_R1     T2_4h_R1  ...  \
# count  1615.000000  1615.000000  1615.000000  1615.000000  1615.000000  ...
# mean     -0.127257     0.171666     0.445456     0.285316     0.181306  ...
# std       0.446452     0.866616     1.908388     2.896906     2.930675  ...
# ...

# %%
data.isnull().sum()
# Out:
# T1_1h_R1    0
# T1_2h_R1    0
# T1_3h_R1    0
# T1_4h_R1    0
# T1_5h_R1    0
# T1_6h_R1    0
# T2_1h_R1    0
# T2_2h_R1    0
# T2_3h_R1    0
# T2_4h_R1    0
# T2_5h_R1    0
# T2_6h_R1    0
# T3_1h_R1    0
# T3_2h_R1    0
# T3_3h_R1    0
# T3_4h_R1    0
# T3_5h_R1    0
# T3_6h_R1    0
# T1_1h_R2    0
# T1_2h_R2    0
# T1_3h_R2    0
# T1_4h_R2    0
# T1_5h_R2    0
# T1_6h_R2    0
# T2_1h_R2    0
# T2_2h_R2    0
# T2_3h_R2    0
# T2_4h_R2    0
# T2_5h_R2    0
# T2_6h_R2    0
# T3_1h_R2    0
# T3_2h_R2    0
# T3_3h_R2    0
# T3_4h_R2    0
# T3_5h_R2    0
# T3_6h_R2    0
# dtype: int64

# %%
fig1, ax1 = plt.subplots()

ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7f170ed8a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f7f170ee080>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7f170ed600>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f7f170ee590>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7f170ee8c0>,
# ...
#  'means': []}

# %%
data.corr()
# Out:
#           T1_1h_R1  T1_2h_R1  T1_3h_R1  T1_4h_R1  T1_5h_R1  T1_6h_R1  \
# T1_1h_R1  1.000000  0.342041  0.140206  0.160123  0.140882  0.080512
# T1_2h_R1  0.342041  1.000000  0.445645  0.411786  0.326056 -0.114110
# T1_3h_R1  0.140206  0.445645  1.000000  0.655504  0.478121  0.381943
# T1_4h_R1  0.160123  0.411786  0.655504  1.000000  0.636321  0.352938
# T1_5h_R1  0.140882  0.326056  0.478121  0.636321  1.000000  0.486260
# T1_6h_R1  0.080512 -0.114110  0.381943  0.352938  0.486260  1.000000
# T2_1h_R1  0.200077  0.153706  0.207322  0.259711  0.146040  0.045245
# T2_2h_R1  0.064087  0.308160  0.290335  0.387222  0.237202 -0.041153
# T2_3h_R1  0.051911  0.247743  0.290600  0.387071  0.209404 -0.032149
# T2_4h_R1  0.020660  0.216123  0.286388  0.410750  0.237059 -0.004452
# T2_5h_R1  0.013621  0.197587  0.289230  0.397084  0.268679  0.017563
# T2_6h_R1 -0.007931  0.204240  0.290490  0.392572  0.217897  0.028349
# T3_1h_R1  0.281954  0.252981  0.306158  0.332905  0.201452  0.076907
# ...

# %%
data_R1 = data[["T1_1h_R1","T1_2h_R1","T1_3h_R1", "T1_4h_R1","T1_5h_R1","T1_6h_R1","T2_1h_R1","T2_2h_R1","T2_3h_R1","T2_4h_R1","T2_5h_R1","T2_6h_R1","T3_1h_R1","T3_2h_R1","T3_3h_R1","T3_4h_R1","T3_5h_R1","T3_6h_R1"]]

# %%
data_R1 
data_R1.corr()
# Out:
#           T1_1h_R1  T1_2h_R1  T1_3h_R1  T1_4h_R1  T1_5h_R1  T1_6h_R1  \
# T1_1h_R1  1.000000  0.342041  0.140206  0.160123  0.140882  0.080512
# T1_2h_R1  0.342041  1.000000  0.445645  0.411786  0.326056 -0.114110
# T1_3h_R1  0.140206  0.445645  1.000000  0.655504  0.478121  0.381943
# T1_4h_R1  0.160123  0.411786  0.655504  1.000000  0.636321  0.352938
# T1_5h_R1  0.140882  0.326056  0.478121  0.636321  1.000000  0.486260
# T1_6h_R1  0.080512 -0.114110  0.381943  0.352938  0.486260  1.000000
# T2_1h_R1  0.200077  0.153706  0.207322  0.259711  0.146040  0.045245
# T2_2h_R1  0.064087  0.308160  0.290335  0.387222  0.237202 -0.041153
# T2_3h_R1  0.051911  0.247743  0.290600  0.387071  0.209404 -0.032149
# T2_4h_R1  0.020660  0.216123  0.286388  0.410750  0.237059 -0.004452
# T2_5h_R1  0.013621  0.197587  0.289230  0.397084  0.268679  0.017563
# T2_6h_R1 -0.007931  0.204240  0.290490  0.392572  0.217897  0.028349
# T3_1h_R1  0.281954  0.252981  0.306158  0.332905  0.201452  0.076907
# ...

# %%
plt.hist(data_R1)
# Out:
# (array([[0.000e+00, 0.000e+00, 1.000e+00, 1.210e+02, 1.485e+03, 8.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 1.000e+00, 2.000e+00, 1.980e+02, 1.380e+03, 3.200e+01,
#          0.000e+00, 2.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 0.000e+00, 3.000e+00, 1.950e+02, 1.389e+03, 2.500e+01,
#          2.000e+00, 1.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 0.000e+00, 1.400e+01, 2.250e+02, 1.340e+03, 3.100e+01,
#          5.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 1.000e+00, 1.500e+01, 2.180e+02, 1.353e+03, 2.700e+01,
#          1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 0.000e+00, 1.300e+01, 2.320e+02, 1.363e+03, 7.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 1.000e+00, 3.000e+00, 2.220e+02, 1.298e+03, 6.700e+01,
#          1.400e+01, 9.000e+00, 0.000e+00, 1.000e+00],
# ...

# %%
data_R2 = data[["T1_1h_R2","T1_2h_R2","T1_3h_R2", "T1_4h_R2","T1_5h_R2","T1_6h_R2","T2_1h_R2","T2_2h_R2","T2_3h_R2","T2_4h_R2","T2_5h_R2","T2_6h_R2","T3_1h_R2","T3_2h_R2","T3_3h_R2","T3_4h_R2","T3_5h_R2","T3_6h_R2"]]

# %%
data_R2.corr()
# Out:
#           T1_1h_R2  T1_2h_R2  T1_3h_R2  T1_4h_R2  T1_5h_R2  T1_6h_R2  \
# T1_1h_R2  1.000000  0.239432  0.295873  0.176697 -0.054820 -0.048616
# T1_2h_R2  0.239432  1.000000  0.672053  0.526759  0.216653  0.120138
# T1_3h_R2  0.295873  0.672053  1.000000  0.327059  0.037586 -0.157858
# T1_4h_R2  0.176697  0.526759  0.327059  1.000000  0.614663  0.490542
# T1_5h_R2 -0.054820  0.216653  0.037586  0.614663  1.000000  0.660373
# T1_6h_R2 -0.048616  0.120138 -0.157858  0.490542  0.660373  1.000000
# T2_1h_R2  0.236195  0.176481  0.306795  0.077342 -0.032633 -0.159065
# T2_2h_R2  0.211292  0.198590  0.377348  0.092787 -0.057322 -0.233317
# T2_3h_R2  0.253129  0.179296  0.403571  0.086189 -0.073893 -0.232468
# T2_4h_R2  0.287469  0.147758  0.342713  0.138411 -0.066209 -0.217675
# T2_5h_R2  0.284609  0.137194  0.336497  0.115229 -0.068289 -0.228696
# T2_6h_R2  0.315355  0.132673  0.375081  0.093161 -0.091853 -0.198196
# T3_1h_R2  0.401174  0.287856  0.353760  0.195076  0.003889 -0.066845
# ...

# %%
plt.hist(data_R2)
# Out:
# (array([[0.000e+00, 0.000e+00, 0.000e+00, 1.300e+01, 1.520e+03, 8.100e+01,
#          1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, 1.600e+01, 1.484e+03, 1.100e+02,
#          3.000e+00, 2.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 0.000e+00, 1.000e+00, 3.500e+01, 1.335e+03, 2.270e+02,
#          1.400e+01, 3.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 0.000e+00, 2.000e+00, 2.200e+01, 1.441e+03, 1.450e+02,
#          5.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 0.000e+00, 1.000e+00, 2.900e+01, 1.446e+03, 1.360e+02,
#          3.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, 2.400e+01, 1.422e+03, 1.670e+02,
#          2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, 4.100e+01, 1.184e+03, 3.540e+02,
#          1.800e+01, 1.300e+01, 4.000e+00, 1.000e+00],
# ...

# %%
data_T1 = data[["T1_1h_R1","T1_2h_R1","T1_3h_R1", "T1_4h_R1","T1_5h_R1","T1_6h_R1","T1_1h_R2","T1_2h_R2","T1_3h_R2","T1_4h_R2","T1_5h_R2","T1_6h_R2"]]

# %%
data_T1.corr()
# Out:
#           T1_1h_R1  T1_2h_R1  T1_3h_R1  T1_4h_R1  T1_5h_R1  T1_6h_R1  \
# T1_1h_R1  1.000000  0.342041  0.140206  0.160123  0.140882  0.080512
# T1_2h_R1  0.342041  1.000000  0.445645  0.411786  0.326056 -0.114110
# T1_3h_R1  0.140206  0.445645  1.000000  0.655504  0.478121  0.381943
# T1_4h_R1  0.160123  0.411786  0.655504  1.000000  0.636321  0.352938
# T1_5h_R1  0.140882  0.326056  0.478121  0.636321  1.000000  0.486260
# T1_6h_R1  0.080512 -0.114110  0.381943  0.352938  0.486260  1.000000
# T1_1h_R2  0.377951  0.165537  0.360799  0.321285  0.240307  0.226285
# T1_2h_R2  0.116770  0.500792  0.623236  0.347696  0.180474  0.074614
# T1_3h_R2  0.173623  0.697757  0.711005  0.606583  0.305153  0.017662
# T1_4h_R2  0.043846  0.038511  0.528998  0.402323  0.283051  0.386270
# T1_5h_R2  0.048778  0.038839  0.223425  0.250781  0.414248  0.343752
# T1_6h_R2  0.014700 -0.109293  0.049052 -0.029618  0.298857  0.481362
#
#           T1_1h_R2  T1_2h_R2  T1_3h_R2  T1_4h_R2  T1_5h_R2  T1_6h_R2
# ...

# %%
data_T2 = data[["T2_1h_R1","T2_2h_R1","T2_3h_R1", "T2_4h_R1","T2_5h_R1","T2_6h_R1","T2_1h_R2","T2_2h_R2","T2_3h_R2","T2_4h_R2","T2_5h_R2","T2_6h_R2"]]

# %%
data_T2.corr()
# Out:
#           T2_1h_R1  T2_2h_R1  T2_3h_R1  T2_4h_R1  T2_5h_R1  T2_6h_R1  \
# T2_1h_R1  1.000000  0.722499  0.568219  0.516132  0.478510  0.429263
# T2_2h_R1  0.722499  1.000000  0.934813  0.888984  0.853695  0.803390
# T2_3h_R1  0.568219  0.934813  1.000000  0.961252  0.937931  0.898643
# T2_4h_R1  0.516132  0.888984  0.961252  1.000000  0.985044  0.951677
# T2_5h_R1  0.478510  0.853695  0.937931  0.985044  1.000000  0.971091
# T2_6h_R1  0.429263  0.803390  0.898643  0.951677  0.971091  1.000000
# T2_1h_R2  0.891736  0.810116  0.685076  0.666003  0.631310  0.596225
# T2_2h_R2  0.666730  0.962132  0.954757  0.903544  0.870318  0.830713
# T2_3h_R2  0.592319  0.951405  0.983098  0.949801  0.921879  0.886849
# T2_4h_R2  0.494316  0.844769  0.938719  0.965488  0.963154  0.939434
# T2_5h_R2  0.468894  0.810781  0.913815  0.954067  0.966926  0.955834
# T2_6h_R2  0.411484  0.779652  0.886097  0.938883  0.961773  0.987313
#
#           T2_1h_R2  T2_2h_R2  T2_3h_R2  T2_4h_R2  T2_5h_R2  T2_6h_R2
# ...

# %%
data_T3 = data[["T3_1h_R1","T3_2h_R1","T3_3h_R1", "T3_4h_R1","T3_5h_R1","T3_6h_R1","T3_1h_R2","T3_2h_R2","T3_3h_R2","T3_4h_R2","T3_5h_R2","T3_6h_R2"]]

# %%
data_T3.corr()
# Out:
#           T3_1h_R1  T3_2h_R1  T3_3h_R1  T3_4h_R1  T3_5h_R1  T3_6h_R1  \
# T3_1h_R1  1.000000  0.760144  0.649316  0.582001  0.535866  0.500390
# T3_2h_R1  0.760144  1.000000  0.949432  0.906702  0.868224  0.819110
# T3_3h_R1  0.649316  0.949432  1.000000  0.960484  0.936505  0.898641
# T3_4h_R1  0.582001  0.906702  0.960484  1.000000  0.982516  0.933792
# T3_5h_R1  0.535866  0.868224  0.936505  0.982516  1.000000  0.955204
# T3_6h_R1  0.500390  0.819110  0.898641  0.933792  0.955204  1.000000
# T3_1h_R2  0.871809  0.785900  0.709649  0.672633  0.644609  0.607612
# T3_2h_R2  0.700036  0.970384  0.966876  0.922650  0.887107  0.846723
# T3_3h_R2  0.646068  0.954645  0.985730  0.965439  0.933360  0.892665
# T3_4h_R2  0.561816  0.882555  0.955023  0.982693  0.978276  0.946735
# T3_5h_R2  0.506911  0.827985  0.910197  0.960558  0.972027  0.965625
# T3_6h_R2  0.477534  0.798469  0.884129  0.932948  0.952989  0.986486
#
#           T3_1h_R2  T3_2h_R2  T3_3h_R2  T3_4h_R2  T3_5h_R2  T3_6h_R2
# ...

# %% [markdown]
# # ACP

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

# %%
data_scale = scale(data)
pca = PCA()
acp = pca.fit(data_scale)

# %%
print(pca.components_)
# Out:
# [[ 0.0148731   0.06249656  0.08730888 ...  0.21055514  0.20520741
#    0.20156672]
#  [ 0.14750555  0.21198114  0.35816627 ... -0.04216449 -0.06194913
#   -0.05752949]
#  [ 0.21518991  0.16353083 -0.03239353 ... -0.10829457 -0.15591228
#   -0.17949079]
#  ...
#  [-0.00821114  0.00819733 -0.01070834 ... -0.10302127  0.09825243
#   -0.00165264]
#  [-0.01141916  0.0097413  -0.01668596 ...  0.02908076 -0.10006467
#    0.04664318]
#  [-0.00211647 -0.00236257  0.01218133 ... -0.08957072  0.4932325
#   -0.52419328]]

# %%
print(pca.explained_variance_)
# Out:
# [2.12904290e+01 4.00574847e+00 2.29157499e+00 2.11213558e+00
#  1.34482565e+00 1.00755532e+00 9.24055969e-01 5.25946557e-01
#  4.87886531e-01 4.18593979e-01 2.79249195e-01 2.42596059e-01
#  2.13131957e-01 1.56748060e-01 1.43391684e-01 1.00693320e-01
#  8.95381301e-02 6.49460325e-02 6.24752178e-02 4.78911728e-02
#  4.39884679e-02 3.47173141e-02 2.21576096e-02 1.84945680e-02
#  1.39262813e-02 1.17180476e-02 1.06604160e-02 8.93410250e-03
#  8.64536474e-03 7.89386546e-03 6.86069983e-03 6.06828840e-03
#  5.45366781e-03 4.86432287e-03 4.77520217e-03 3.73370461e-03]

# %%
plt.plot(pca.explained_variance_)

# %%
plt.plot(pca.explained_variance_ratio_)

# %%
eig = pd.DataFrame(
    {
        "Dimension" : ["Dim" + str(x + 1) for x in range(36)], 
        "Variance expliquée" : pca.explained_variance_,
        "% variance expliquée" : np.round(pca.explained_variance_ratio_ * 100),
        "% cum. var. expliquée" : np.round(np.cumsum(pca.explained_variance_ratio_) * 100)
    }
)
eig
# Out:
#    Dimension  Variance expliquée  % variance expliquée  % cum. var. expliquée
# 0       Dim1           21.290429                  59.0                   59.0
# 1       Dim2            4.005748                  11.0                   70.0
# 2       Dim3            2.291575                   6.0                   77.0
# 3       Dim4            2.112136                   6.0                   82.0
# 4       Dim5            1.344826                   4.0                   86.0
# 5       Dim6            1.007555                   3.0                   89.0
# 6       Dim7            0.924056                   3.0                   92.0
# 7       Dim8            0.525947                   1.0                   93.0
# 8       Dim9            0.487887                   1.0                   94.0
# 9      Dim10            0.418594                   1.0                   96.0
# 10     Dim11            0.279249                   1.0                   96.0
# ...

# %%
plt.plot(np.round(np.cumsum(pca.explained_variance_ratio_) * 100))

# %%
coord1=pca.components_[0]*np.sqrt(pca.explained_variance_[0])
coord2=pca.components_[1]*np.sqrt(pca.explained_variance_[1])
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1, 1, 1)
for i, j, nom in zip(coord1,coord2, data.columns):
    plt.text(i, j, nom)
    plt.arrow(0,0,i,j,color='black')
plt.axis((-1.2,1.2,-1.2,1.2))
# cercle
c=plt.Circle((0,0), radius=1, color='gray', fill=False)
ax.add_patch(c)
plt.show()

# %%
eig.plot.bar(x = "Dimension", y = "% variance expliquée") # permet un diagramme en barres
plt.text(5, 18, "17%") # ajout de texte
plt.axhline(y = 17, linewidth = .5, color = "dimgray", linestyle = "--") # ligne 17 = 100 / 6 (nb dimensions)
plt.show()

# %%
data_acp = pca.fit(data).transform(data)
data_acp_df = pd.DataFrame(data_acp)
data_acp_df
# Out:
#              0         1         2         3         4         5         6   \
# 0      7.864463 -4.647386  1.055120  0.364095  0.114657 -0.671702  0.172164
# 1     10.520293  1.212568 -0.265833  0.831633  0.213551 -0.348951 -0.536194
# 2    -12.945753  1.000410  0.786758 -0.633360  0.191546  0.714793  0.657032
# 3      4.878327 -2.434584 -0.022466 -1.535762  0.556715  0.631384  0.181067
# 4    -13.527698 -1.156260  0.203230  0.061024  1.366140 -0.659360 -1.106433
# ...         ...       ...       ...       ...       ...       ...       ...
# 1610   8.999392  0.345379 -0.349662  0.316001 -0.163130 -0.199803  0.221404
# 1611 -13.008166  0.024532  0.865537 -0.339719  1.659285 -0.874939  0.474575
# 1612   7.968859 -1.167348 -0.220266  0.230708 -0.206787 -0.406986  0.248589
# 1613 -10.221583 -1.693078 -0.058021 -0.961038  2.096565 -0.164543  0.180303
# 1614   3.292680 -3.063996  0.170373  0.031144 -1.473496  1.473564  0.731573
#
# ...

# %%
plt.scatter(data_acp[:,0], data_acp[:,1])
plt.xlabel("Dimension 1 ") # modification du nom de l'axe X
plt.ylabel("Dimension 2 ") # idem pour axe Y
plt.suptitle("Premier plan factoriel ") # titre général
plt.show()
